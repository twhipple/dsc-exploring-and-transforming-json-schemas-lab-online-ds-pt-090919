# %% [markdown]
# # Exploring and Transforming JSON Schemas

# %% [markdown]
# # Introduction
#
# In this lesson, you'll formalize how to explore a JSON file whose structure and schema is unknown to you. This often happens in practice when you are handed a file or stumble upon one with little documentation.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Use the JSON module to load and parse JSON documents
# * Load and explore unknown JSON schemas
# * Convert JSON to a pandas dataframe

# %% [markdown]
# ## Loading the JSON file
#
# Load the data from the file `disease_data.json`.

# %%
#Your code here 
import json
f = open('disease_data.json')
data = json.load(f)

# %% [markdown]
# ## Explore the first and second levels of the schema hierarchy

# %%
#Your code here
type(data)
# Out:
# dict

# %%
data.keys()
# Out:
# dict_keys(['meta', 'data'])

# %%
print(type(data['meta']))
print(type(data['data']))
# Out:
# <class 'dict'>
# <class 'list'>

# %%
data['meta'].keys()
# Out:
# dict_keys(['view'])

# %%
print(data['meta']['view'].keys())
len(data['meta']['view'].keys())
# Out:
# dict_keys(['id', 'name', 'attribution', 'attributionLink', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'licenseId', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'license', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])
# 40

# %%
for key in data['meta']['view'].keys():
    print(key, type(data['meta']['view'][key]))
# Out:
# id <class 'str'>
# name <class 'str'>
# attribution <class 'str'>
# attributionLink <class 'str'>
# averageRating <class 'int'>
# category <class 'str'>
# createdAt <class 'int'>
# description <class 'str'>
# displayType <class 'str'>
# downloadCount <class 'int'>
# hideFromCatalog <class 'bool'>
# hideFromDataJson <class 'bool'>
# indexUpdatedAt <class 'int'>
# licenseId <class 'str'>
# newBackend <class 'bool'>
# numberOfComments <class 'int'>
# oid <class 'int'>
# provenance <class 'str'>
# publicationAppendEnabled <class 'bool'>
# publicationDate <class 'int'>
# publicationGroup <class 'int'>
# publicationStage <class 'str'>
# rowClass <class 'str'>
# rowsUpdatedAt <class 'int'>
# rowsUpdatedBy <class 'str'>
# tableId <class 'int'>
# totalTimesRated <class 'int'>
# viewCount <class 'int'>
# viewLastModified <class 'int'>
# viewType <class 'str'>
# columns <class 'list'>
# grants <class 'list'>
# license <class 'dict'>
# metadata <class 'dict'>
# owner <class 'dict'>
# query <class 'dict'>
# rights <class 'list'>
# tableAuthor <class 'dict'>
# tags <class 'list'>
# flags <class 'list'>

# %%
len(data['data'][0])
# Out:
# 42

# %%
data['data'][0]
# Out:
# [1,
#  'FF49C41F-CE8D-46C4-9164-653B1227CF6F',
#  1,
#  1527194521,
#  '959778',
#  1527194521,
#  '959778',
#  None,
#  '2016',
#  '2016',
#  'US',
#  'United States',
#  'BRFSS',
#  'Alcohol',
#  'Binge drinking prevalence among adults aged >= 18 years',
#  None,
#  '%',
#  'Crude Prevalence',
#  '16.9',
#  '16.9',
#  '*',
#  '50 States + DC: US Median',
#  '16',
#  '18',
#  'Overall',
#  'Overall',
#  None,
#  None,
#  None,
#  None,
#  [None, None, None, None, None],
#  None,
#  '59',
#  'ALC',
#  'ALC2_2',
#  'CRDPREV',
#  'OVERALL',
#  'OVR',
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# ## Convert to a DataFrame
#
# Create a DataFrame from the JSON file. Be sure to retrive the column names for the dataframe. (Search within the 'meta' key of the master dictionary.) The DataFrame should include all 42 columns.

# %%
#Your code here
import pandas as pd
df = pd.DataFrame(data['meta'])
print(len(df))
df.head(40)
# Out:
# 40
#                                                                        view
# attribution               Centers for Disease Control and Prevention, Na...
# attributionLink                             http://www.cdc.gov/nccdphp/dph/
# averageRating                                                             0
# category                                         Chronic Disease Indicators
# columns                   [{'id': -1, 'name': 'sid', 'dataTypeName': 'me...
# createdAt                                                        1463517008
# description               CDC's Division of Population Health provides c...
# displayType                                                           table
# downloadCount                                                         80068
# flags                         [default, restorable, restorePossibleForType]
# grants                    [{'inherited': False, 'type': 'viewer', 'flags...
# hideFromCatalog                                                       False
# hideFromDataJson                                                      False
# id                                                                g4ie-h725
# indexUpdatedAt                                                   1531158109
# license                                           {'name': 'Public Domain'}
# licenseId                                                     PUBLIC_DOMAIN
# metadata                  {'rdfSubject': '0', 'rdfClass': '', 'custom_fi...
# name                                  U.S. Chronic Disease Indicators (CDI)
# newBackend                                                            False
# numberOfComments                                                          0
# oid                                                                28887577
# owner                     {'id': 'isr2-3jff', 'displayName': 'DPH Public...
# provenance                                                         official
# publicationAppendEnabled                                              False
# publicationDate                                                  1527195619
# publicationGroup                                                   10787757
# publicationStage                                                  published
# query                                                                    {}
# rights                                                               [read]
# rowClass
# rowsUpdatedAt                                                    1527194748
# rowsUpdatedBy                                                     fwb6-kmt3
# tableAuthor               {'id': 'isr2-3jff', 'displayName': 'DPH Public...
# tableId                                                            15222261
# tags                      [cdi, chronic disease indicators, alcohol, art...
# totalTimesRated                                                           0
# viewCount                                                             15880
# viewLastModified                                                 1531157635
# viewType                                                            tabular

# %%
data['meta']['view'].keys()
# Out:
# dict_keys(['id', 'name', 'attribution', 'attributionLink', 'averageRating', 'category', 'createdAt', 'description', 'displayType', 'downloadCount', 'hideFromCatalog', 'hideFromDataJson', 'indexUpdatedAt', 'licenseId', 'newBackend', 'numberOfComments', 'oid', 'provenance', 'publicationAppendEnabled', 'publicationDate', 'publicationGroup', 'publicationStage', 'rowClass', 'rowsUpdatedAt', 'rowsUpdatedBy', 'tableId', 'totalTimesRated', 'viewCount', 'viewLastModified', 'viewType', 'columns', 'grants', 'license', 'metadata', 'owner', 'query', 'rights', 'tableAuthor', 'tags', 'flags'])

# %%
df2 = pd.DataFrame(data['data'])
print(len(df2))
df2.head()
# Out:
# 60266
#    0                                     1   2           3       4   \
# 0   1  FF49C41F-CE8D-46C4-9164-653B1227CF6F   1  1527194521  959778
# 1   2  F4468C3D-340A-4CD2-84A3-DF554DFF065E   2  1527194521  959778
# 2   3  65609156-A343-4869-B03F-2BA62E96AC19   3  1527194521  959778
# 3   4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3   4  1527194521  959778
# 4   5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B   5  1527194521  959778
#
#            5       6     7     8     9   ...   32   33      34       35  \
# 0  1527194521  959778  None  2016  2016  ...   59  ALC  ALC2_2  CRDPREV
# 1  1527194521  959778  None  2016  2016  ...   01  ALC  ALC2_2  CRDPREV
# 2  1527194521  959778  None  2016  2016  ...   02  ALC  ALC2_2  CRDPREV
# 3  1527194521  959778  None  2016  2016  ...   04  ALC  ALC2_2  CRDPREV
# 4  1527194521  959778  None  2016  2016  ...   05  ALC  ALC2_2  CRDPREV
#
#         36   37    38    39    40    41
# 0  OVERALL  OVR  None  None  None  None
# 1  OVERALL  OVR  None  None  None  None
# 2  OVERALL  OVR  None  None  None  None
# 3  OVERALL  OVR  None  None  None  None
# 4  OVERALL  OVR  None  None  None  None
#
# [5 rows x 42 columns]

# %%
df3 = pd.DataFrame(data['data'])
cols = [i['name'] for i in data['meta']['view']['columns']]
df3.columns = cols
df3.head()
# Out:
#    sid                                    id  position  created_at  \
# 0    1  FF49C41F-CE8D-46C4-9164-653B1227CF6F         1  1527194521
# 1    2  F4468C3D-340A-4CD2-84A3-DF554DFF065E         2  1527194521
# 2    3  65609156-A343-4869-B03F-2BA62E96AC19         3  1527194521
# 3    4  0DB09B00-EFEB-4AC0-9467-A7CBD2B57BF3         4  1527194521
# 4    5  D98DA5BA-6FD6-40F5-A9B1-ABD45E44967B         5  1527194521
#
#   created_meta  updated_at updated_meta  meta YearStart YearEnd  \
# 0       959778  1527194521       959778  None      2016    2016
# 1       959778  1527194521       959778  None      2016    2016
# 2       959778  1527194521       959778  None      2016    2016
# 3       959778  1527194521       959778  None      2016    2016
# 4       959778  1527194521       959778  None      2016    2016
#
#          ...        LocationID TopicID QuestionID DataValueTypeID  \
# 0        ...                59     ALC     ALC2_2         CRDPREV
# 1        ...                01     ALC     ALC2_2         CRDPREV
# 2        ...                02     ALC     ALC2_2         CRDPREV
# 3        ...                04     ALC     ALC2_2         CRDPREV
# 4        ...                05     ALC     ALC2_2         CRDPREV
#
#   StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 0                   OVERALL               OVR                      None
# 1                   OVERALL               OVR                      None
# 2                   OVERALL               OVR                      None
# 3                   OVERALL               OVR                      None
# 4                   OVERALL               OVR                      None
#
#   StratificationID2 StratificationCategoryID3 StratificationID3
# 0              None                      None              None
# 1              None                      None              None
# 2              None                      None              None
# 3              None                      None              None
# 4              None                      None              None
#
# [5 rows x 42 columns]

# %% [markdown]
# ## Level-Up
# ## Create a bar graph of states with the highest asthma rates for adults age 18+

# %%
#Their code:
df3[df3.Topic == 'Asthma'].Question.value_counts(normalize=True).cumsum()[:10]
# Out:
# Pneumococcal vaccination among noninstitutionalized adults aged >= 65 years with asthma    0.186096
# Influenza vaccination among noninstitutionalized adults aged 18-64 years with asthma       0.372193
# Current asthma prevalence among adults aged >= 18 years                                    0.558289
# Influenza vaccination among noninstitutionalized adults aged >= 65 years with asthma       0.744385
# Pneumococcal vaccination among noninstitutionalized adults aged 18-64 years with asthma    0.930481
# Asthma prevalence among women aged 18-44 years                                             1.000000
# Name: Question, dtype: float64

# %%
df3[df3.Topic == 'Asthma']
# Out:
#          sid                                    id  position  created_at  \
# 4725    4726  786EA689-97C8-45C7-B733-9CF01D8AEB62      4726  1527194522
# 5529    5530  AC33E8A2-F507-48D5-B02C-9179EDC425E3      5530  1527194522
# 5632    5633  1E855D58-2A98-44E2-A062-AE1E8A2F7DB6      5633  1527194522
# 6777    6778  D300D76F-6293-4C41-B47F-AB8A93426EE2      6778  1527194522
# 7034    7035  5868F7F7-82F1-4D72-A144-767DFA87D581      7035  1527194522
# 7102   10245  6A49F874-7FD9-42E6-B7F0-50BA588CA63F     10245  1527194523
# 14027       959778  1527194524       959778  None      2016    2016
# 14028       959778  1527194524       959778  None      2016    2016
# 14029       959778  1527194524       959778  None      2016    2016
# 14030       959778  1527194524       959778  None      2016    2016
# 14031       959778  1527194524       959778  None      2016    2016
# 14032       959778  1527194524       959778  None      2016    2016
# 14033       959778  1527194524       959778  None      2016    2016
# 14034       959778  1527194524       959778  None      2016    2016
# 14035       959778  1527194524       959778  None      2016    2016
# 14036       959778  1527194524       959778  None      2016    2016
# 14037       959778  1527194524       959778  None      2016    2016
# 14038       959778  1527194524       959778  None      2016    2016
# 14039       959778  1527194524       959778  None      2016    2016
# 14040       959778  1527194524       959778  None      2016    2016
# 14041       959778  1527194524       959778  None      2016    2016
# 14042       959778  1527194524       959778  None      2016    2016
# 14043       959778  1527194524       959778  None      2016    2016
# 14044       959778  1527194524       959778  None      2016    2016
# 14045       959778  1527194524       959778  None      2016    2016
# 14046       959778  1527194524       959778  None      2016    2016
# 14047       959778  1527194524       959778  None      2016    2016
# 14048       959778  1527194524       959778  None      2016    2016
# 14049       959778  1527194524       959778  None      2016    2016
# 14050       959778  1527194524       959778  None      2016    2016
# 14051       959778  1527194524       959778  None      2016    2016
# 14052       959778  1527194524       959778  None      2016    2016
# 14053       959778  1527194524       959778  None      2016    2016
#
#              ...        LocationID TopicID QuestionID DataValueTypeID  \
# 4725         ...                17     AST     AST1_1         CRDPREV
# 5529         ...                18     AST     AST1_1         CRDPREV
# 5632         ...                19     AST     AST1_1         CRDPREV
# 6777         ...                20     AST     AST1_1         CRDPREV
# 7034         ...                21     AST     AST1_1         CRDPREV
# 7102         ...                27     AST     AST1_2         CRDPREV
# 7337         ...                22     AST     AST1_1         CRDPREV
# 7428         ...                23     AST     AST1_1         CRDPREV
# 7499         ...                24     AST     AST1_1         CRDPREV
# 7966         ...                50     AST     AST1_1         CRDPREV
# 8114         ...                51     AST     AST1_1         CRDPREV
# 8135         ...                12     AST     AST1_1         CRDPREV
# 8234         ...                66     AST     AST1_1      AGEADJPREV
# 8313         ...                28     AST     AST1_2         CRDPREV
# 8645         ...                20     AST     AST1_2         CRDPREV
# 8738         ...                21     AST     AST1_2         CRDPREV
# 9000         ...                22     AST     AST1_2         CRDPREV
# 9138         ...                15     AST     AST1_1         CRDPREV
# 9218         ...                16     AST     AST1_1         CRDPREV
# 9296         ...                29     AST     AST1_2         CRDPREV
# 9370         ...                59     AST     AST1_1         CRDPREV
# 9371         ...                01     AST     AST1_1         CRDPREV
# 9372         ...                02     AST     AST1_1         CRDPREV
# 9373         ...                04     AST     AST1_1         CRDPREV
# 9374         ...                05     AST     AST1_1         CRDPREV
# 9375         ...                06     AST     AST1_1         CRDPREV
# 9376         ...                08     AST     AST1_1         CRDPREV
# 9377         ...                09     AST     AST1_1         CRDPREV
# 9378         ...                10     AST     AST1_1         CRDPREV
# 9379         ...                11     AST     AST1_1         CRDPREV
# ...          ...               ...     ...        ...             ...
# 14024        ...                28     AST     AST6_2      AGEADJPREV
# 14025        ...                29     AST     AST6_2      AGEADJPREV
# 14026        ...                30     AST     AST6_2      AGEADJPREV
# 14027        ...                31     AST     AST6_2      AGEADJPREV
# 14028        ...                32     AST     AST6_2      AGEADJPREV
# 14029        ...                33     AST     AST6_2      AGEADJPREV
# 14030        ...                34     AST     AST6_2      AGEADJPREV
# 14031        ...                35     AST     AST6_2      AGEADJPREV
# 14032        ...                36     AST     AST6_2      AGEADJPREV
# 14033        ...                37     AST     AST6_2      AGEADJPREV
# 14034        ...                38     AST     AST6_2      AGEADJPREV
# 14035        ...                39     AST     AST6_2      AGEADJPREV
# 14036        ...                40     AST     AST6_2      AGEADJPREV
# 14037        ...                41     AST     AST6_2      AGEADJPREV
# 14038        ...                42     AST     AST6_2      AGEADJPREV
# 14039        ...                44     AST     AST6_2      AGEADJPREV
# 14040        ...                45     AST     AST6_2      AGEADJPREV
# 14041        ...                46     AST     AST6_2      AGEADJPREV
# 14042        ...                47     AST     AST6_2      AGEADJPREV
# 14043        ...                48     AST     AST6_2      AGEADJPREV
# 14044        ...                49     AST     AST6_2      AGEADJPREV
# 14045        ...                50     AST     AST6_2      AGEADJPREV
# 14046        ...                51     AST     AST6_2      AGEADJPREV
# 14047        ...                53     AST     AST6_2      AGEADJPREV
# 14048        ...                54     AST     AST6_2      AGEADJPREV
# 14049        ...                55     AST     AST6_2      AGEADJPREV
# 14050        ...                56     AST     AST6_2      AGEADJPREV
# 14051        ...                66     AST     AST6_2      AGEADJPREV
# 14052        ...                72     AST     AST6_2      AGEADJPREV
# 14053        ...                78     AST     AST6_2      AGEADJPREV
#
#       StratificationCategoryID1 StratificationID1 StratificationCategoryID2  \
# 4725                     GENDER              GENM                      None
# 5529                     GENDER              GENM                      None
# 5632                     GENDER              GENM                      None
# 6777                     GENDER              GENM                      None
# 7034                     GENDER              GENM                      None
# 7102                    OVERALL               OVR                      None
# 7337                     GENDER              GENM                      None
# 7428                     GENDER              GENM                      None
# 7499                     GENDER              GENM                      None
# 7966                     GENDER              GENM                      None
# 8114                     GENDER              GENM                      None
# 8135                     GENDER              GENF                      None
# 8234                     GENDER              GENF                      None
# 8313                    OVERALL               OVR                      None
# 8645                    OVERALL               OVR                      None
# 8738                    OVERALL               OVR                      None
# 9000                    OVERALL               OVR                      None
# 9138                     GENDER              GENM                      None
# 9218                     GENDER              GENM                      None
# 9296                    OVERALL               OVR                      None
# 9370                    OVERALL               OVR                      None
# 9371                    OVERALL               OVR                      None
# 9372                    OVERALL               OVR                      None
# 9373                    OVERALL               OVR                      None
# 9374                    OVERALL               OVR                      None
# 9375                    OVERALL               OVR                      None
# 9376                    OVERALL               OVR                      None
# 9377                    OVERALL               OVR                      None
# 9378                    OVERALL               OVR                      None
# 9379                    OVERALL               OVR                      None
# ...                         ...               ...                       ...
# 14024                      RACE               MRC                      None
# 14025                      RACE               MRC                      None
# 14026                      RACE               MRC                      None
# 14027                      RACE               MRC                      None
# 14028                      RACE               MRC                      None
# 14029                      RACE               MRC                      None
# 14030                      RACE               MRC                      None
# 14031                      RACE               MRC                      None
# 14032                      RACE               MRC                      None
# 14033                      RACE               MRC                      None
# 14034                      RACE               MRC                      None
# 14035                      RACE               MRC                      None
# 14036                      RACE               MRC                      None
# 14037                      RACE               MRC                      None
# 14038                      RACE               MRC                      None
# 14039                      RACE               MRC                      None
# 14040                      RACE               MRC                      None
# 14041                      RACE               MRC                      None
# 14042                      RACE               MRC                      None
# 14043                      RACE               MRC                      None
# 14044                      RACE               MRC                      None
# 14045                      RACE               MRC                      None
# 14046                      RACE               MRC                      None
# 14047                      RACE               MRC                      None
# 14048                      RACE               MRC                      None
# 14049                      RACE               MRC                      None
# 14050                      RACE               MRC                      None
# 14051                      RACE               MRC                      None
# 14052                      RACE               MRC                      None
# 14053                      RACE               MRC                      None
#
#       StratificationID2 StratificationCategoryID3 StratificationID3
# 4725               None                      None              None
# 5529               None                      None              None
# 5632               None                      None              None
# 6777               None                      None              None
# 7034               None                      None              None
# 7102               None                      None              None
# 7337               None                      None              None
# 7428               None                      None              None
# 7499               None                      None              None
# 7966               None                      None              None
# 8114               None                      None              None
# 8135               None                      None              None
# 8234               None                      None              None
# 8313               None                      None              None
# 8645               None                      None              None
# 8738               None                      None              None
# 9000               None                      None              None
# 9138               None                      None              None
# 9218               None                      None              None
# 9296               None                      None              None
# 9370               None                      None              None
# 9371               None                      None              None
# 9372               None                      None              None
# 9373               None                      None              None
# 9374               None                      None              None
# 9375               None                      None              None
# 9376               None                      None              None
# 9377               None                      None              None
# 9378               None                      None              None
# 9379               None                      None              None
# ...                 ...                       ...               ...
# 14024              None                      None              None
# 14025              None                      None              None
# 14026              None                      None              None
# 14027              None                      None              None
# 14028              None                      None              None
# 14029              None                      None              None
# 14030              None                      None              None
# 14031              None                      None              None
# 14032              None                      None              None
# 14033              None                      None              None
# 14034              None                      None              None
# 14035              None                      None              None
# 14036              None                      None              None
# 14037              None                      None              None
# 14038              None                      None              None
# 14039              None                      None              None
# 14040              None                      None              None
# 14041              None                      None              None
# 14042              None                      None              None
# 14043              None                      None              None
# 14044              None                      None              None
# 14045              None                      None              None
# 14046              None                      None              None
# 14047              None                      None              None
# 14048              None                      None              None
# 14049              None                      None              None
# 14050              None                      None              None
# 14051              None                      None              None
# 14052              None                      None              None
# 14053              None                      None              None
#
# [4675 rows x 42 columns]

# %%
# Their code
cols = ['LocationAbbr', 'LocationDesc', 'DataSource','Topic', 'Question', 'YearStart', 'YearEnd', 'DataValue']
view = df3[df3.Question == 'Current asthma prevalence among adults aged >= 18 years'][cols]
view.head()
# Out:
#      LocationAbbr LocationDesc DataSource   Topic  \
# 4725           IL     Illinois      BRFSS  Asthma
# 5529           IN      Indiana      BRFSS  Asthma
# 5632           IA         Iowa      BRFSS  Asthma
# 6777           KS       Kansas      BRFSS  Asthma
# 7034           KY     Kentucky      BRFSS  Asthma
#
#                                                Question YearStart YearEnd  \
# 4725  Current asthma prevalence among adults aged >=...      2016    2016
# 5529  Current asthma prevalence among adults aged >=...      2016    2016
# 5632  Current asthma prevalence among adults aged >=...      2016    2016
# 6777  Current asthma prevalence among adults aged >=...      2016    2016
# 7034  Current asthma prevalence among adults aged >=...      2016    2016
#
#      DataValue
# 4725       6.5
# 5529       6.7
# 5632       5.6
# 6777       6.1
# 7034       6.9

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Their code
view.DataValue = view.DataValue.astype(float)
view = view.sort_values(by='DataValue')
view.set_index('LocationAbbr')['DataValue'].plot(kind='bar', figsize=(10,10))
plt.title('Asthma Rates by State 2016')
plt.ylabel('Percent 18+ with Asthma')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %% [markdown]
# ## Summary
#
# Well done! In this lab you got some extended practice exploring the structure of JSON files, converting json files to pandas DataFrame, and visualizing data!
